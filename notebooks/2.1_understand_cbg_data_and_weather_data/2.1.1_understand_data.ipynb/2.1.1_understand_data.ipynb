# %%
import pandas as pd 
import os
import seaborn as sns
import matplotlib.pyplot as plt
# Set the maximum number of rows and columns to display
pd.set_option('display.max_rows', 200)  # Adjust this number as needed
pd.set_option('display.max_columns', 50)  # Adjust this number as needed

# %%
cbg_features = pd.read_csv('../../../data_CityEvent/cbg_features/CBG_COVID_19.csv')
cbg_features.reset_index(drop=True, inplace=True)
cbg_features.shape
# Out:
# (215313, 75)

# %%
cbg_features.head()
# Out:
#    Unnamed: 0       BGFIPS  Total_Population  LUM_Race  Median_income  \
# 0           0  10010201001             730.0  0.501692        35703.0
# 1           1  10010201002            1263.0  0.387580        79000.0
# 2           2  10010202001             835.0  0.766187        26500.0
# 3           3  10010202002            1124.0  0.722437        51042.0
# 4           4  10010203001            2774.0  0.641478        59048.0
#
#    Rent_to_Income    GINI  Agriculture_R  Mining_R  Construction_R  \
# 0            44.5  0.4979            0.0       0.0        2.250804
# 1            17.5  0.4979            0.0       0.0        6.708268
# 2            51.0  0.4231            0.0       0.0        1.976285
# 3            26.3  0.4231            0.0       0.0        2.765957
# 4            23.4  0.3935            0.0       0.0        6.052270
#
#    Manufacturing_R  Wholesale_R   Retail_R  Transportation_R  Utilities_R  \
# ...

# %%
# weather
weather = pd.read_csv('../../../data_CityEvent/Weather/Hourly_Weather_Data-1-OBSERVATION_TIME_IN_UTC_STRING_AS_YYYYMMDDHHMM_-2018-01-01.csv.gz')
weather.shape
# Out:
# (1525262, 34)

# %%
display(weather.head())
# Out:
#   CITY_LOCATION_IDENTIFIER_UP_TO_9_ALPHANUMERIC_CHARACTERS_  \
# 0                                               K04W
# 1                                               K04W
# 2                                               K04W
# 3                                               K04W
# 4                                               K04W
#
#   OBSERVATION_TIME_IN_UTC_STRING_AS_YYYYMMDDHHMM_  \
# 0                         2018-01-01 06:00:00.000
# 1                         2018-01-01 07:00:00.000
# 2                         2018-01-01 08:00:00.000
# 3                         2018-01-01 09:00:00.000
# 4                         2018-01-01 10:00:00.000
#
#   OBSERVATION_TIME_IN_LST_LOCAL_STANDARD_TIME_STRING_AS_YYYYMMDDHHMM_  \
# 0                            2018-01-01 00:00:00.000
# 1                            2018-01-01 01:00:00.000
# 2                            2018-01-01 02:00:00.000
# 3                            2018-01-01 03:00:00.000
# ...
