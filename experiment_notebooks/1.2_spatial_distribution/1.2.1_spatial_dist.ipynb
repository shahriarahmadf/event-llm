# %%
import folium 
import pandas as pd
import json
import os
# Set the maximum number of rows and columns to display
pd.set_option('display.max_rows', 200)  # Adjust this number as needed
pd.set_option('display.max_columns', 50)  # Adjust this number as needed

# %%
import json
from shapely.geometry import Point, MultiPolygon, Polygon
import contextily as ctx
import geopandas as gpd
import matplotlib.pyplot as plt

# Define a function to safely extract coordinates or create geometry
def extract_geometry(geo_json_str):
    try:
        geo_dict = json.loads(geo_json_str)
        if 'coordinates' in geo_dict:
            coords = geo_dict['coordinates']
            if geo_dict['type'] == 'Point' and len(coords) == 2:
                return Point(coords)  # Return Point geometry
            elif geo_dict['type'] == 'MultiPolygon':
                # Convert to MultiPolygon
                polygons = [Polygon(polygon[0]) for polygon in coords if len(polygon) > 0]
                return MultiPolygon(polygons) if polygons else None
        return None  # Invalid geometry type
    except (json.JSONDecodeError, TypeError, ValueError):
        return None  # Handle parsing errors

# Apply the function to extract geometry
def spatial_dist_of_events(df, events_dataframe_name='events'):
    df['geometry'] = df['GEO'].apply(extract_geometry)

    # Filter out rows with missing or invalid geometries
    valid_locations = df.dropna(subset=['geometry'])

    # Create a GeoDataFrame
    gdf = gpd.GeoDataFrame(valid_locations, geometry='geometry')

    # Set the original CRS (WGS84 - EPSG:4326)
    gdf.set_crs(epsg=4326, inplace=True)

    # Convert to Web Mercator (EPSG:3857) for compatibility with contextily basemaps
    gdf = gdf.to_crs(epsg=3857)

    # Plot the points and multipolygons with different colors based on the 'CATEGORY' column
    ax = gdf.plot(column='CATEGORY', cmap='Set1', legend=True, figsize=(20, 14), markersize=3, alpha=0.6)

    # Add a basemap from contextily
    ctx.add_basemap(ax, crs=gdf.crs)

    # Title
    plt.title(f"Spatial distribution of {events_dataframe_name}")

    # Save the figure before displaying it
    plt.savefig(f'../../results/1.2_spatial_distribution/{events_dataframe_name}.PNG', bbox_inches='tight', dpi=300)
    plt.show()

# %%
# Specify the folder path 
folder_path = '../../data_CityEvent/processed/1.4_updated_events_cbgid_assigned_by_category'
file_names = os.listdir(folder_path)

# %%
attended_df = pd.DataFrame()
for file_name in file_names:
    if file_name[0] == 'a' or file_name[0] == 'u':
        continue
    print(file_name)
    df = pd.read_csv(f'../../data_CityEvent/processed/1.4.4_updated_cbgid_downscaled/{file_name}')
    print(df.shape)
    df = df[df['EVENT_ID'].duplicated(keep=False) == False]
    print(df.shape)

    non_attended_df = pd.concat([attended_df, df], ignore_index=True)
    print(attended_df.shape)

# %%
# read events

df_attended_events = pd.read_csv('../../data_CityEvent/Cityevents/Demand_Intelligence_for_Attended_Events_California-0.csv')

# %%
spatial_dist_of_events(df_attended_events, 'attended events')

# %%
df_non_attended_events = pd.read_csv('../../data_CityEvent/Cityevents/Demand_Intelligence_for_Non_Attended_Events_California-0.csv')

# %%
df_non_attended_events.shape
# Out:
# (20070, 32)

# %%
school_holidays = df_non_attended_events[df_non_attended_events['CATEGORY'] == 'school-holidays']
display(school_holidays.shape)
# Out:
# (13057, 32)

# %%
import random
# Generate a random number between 0 and 13057
x = random.randint(0, 13057)
print(x)
# Out:
# 4449

# %%
import random
# Generate a random number between 0 and 13057
x = random.randint(0, 13057)
print(x)
print(school_holidays.iloc[x]['GEO'])
# Out:
# 9918
# {"coordinates":[[[-118.04988399999999,34.09647499999998],[-118.05514799999997,34.12220000000004],[-118.05500700000003,34.12348399999997],[-118.05584799999998,34.123362],[-118.05579700000003,34.123186000000004],[-118.05633299999997,34.12310900000003],[-118.05648500000002,34.123872000000006],[-118.05594899999998,34.123946999999994],[-118.05607400000002,34.124524000000044],[-118.05675199999999,34.124502],[-118.05672100000001,34.12514200000002],[-118.05642199999996,34.12519800000003],[-118.05657300000001,34.125831000000005],[-118.05761599999998,34.12568000000003],[-118.05740700000001,34.124597000000044],[-118.057847,34.12453000000001],[-118.05807299999996,34.12561399999999],[-118.06730100000001,34.124273999999964],[-118.06736599999996,34.13076199999997],[-118.073177,34.13040699999999],[-118.07295600000002,34.123001999999964],[-118.08156500000001,34.12104399999996],[-118.08151299999997,34.11739700000001],[-118.08065099999996,34.113517999999964],[-118.08230199999997,34.11350700000003],[-118.08220999999999,34.106266999999974],[-118.07349400000003,34.10630999999998],[-118.073322,34.090560000000046],[-118.06614099999996,34.0882],[-118.04889499999996,34.09069999999999],[-118.04893799999996,34.091849000000025],[-118.04988399999999,34.09647499999998]]],"type":"Polygon"}

# %%
import geopandas as gpd
from shapely.geometry import shape
import matplotlib.pyplot as plt

def multipolygon_plotter(multipolygon_data):
    multipolygon_data = json.loads(multipolygon_data)
    # Create the geometry from the coordinates
    geometry = shape(multipolygon_data)

    # Create a GeoDataFrame
    gdf = gpd.GeoDataFrame({"geometry": [geometry]}, crs="EPSG:4326")

    # Plot the multipolygon
    gdf.plot(edgecolor='k', color='lightblue')
    plt.title("Multipolygon Plot")
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.show()

# %%
x = random.randint(0, 13057)
print(x)
print(school_holidays.iloc[x]['GEO'])
multipolygon_plotter(school_holidays.iloc[x]['GEO'])
# Out:
# 9777
# {"coordinates":[[[[-122.00931699999998,37.27866600000004],[-122.00671399999999,37.28119700000002],[-122.00587900000001,37.285482],[-122.01983899999998,37.286432],[-122.01517000000003,37.282600000000016],[-122.02311,37.28406300000001],[-122.04577799999998,37.28377000000001],[-122.04573899999995,37.279241999999996],[-122.05927199999996,37.279108000000015],[-122.05940800000002,37.28273999999997],[-122.06399900000001,37.28271700000002],[-122.06403799999995,37.28635099999996],[-122.06851799999998,37.28627299999999],[-122.06856799999996,37.27196000000002],[-122.07535999999998,37.27203500000001],[-122.07573799999999,37.27043],[-122.07757200000003,37.27053000000001],[-122.07758299999996,37.27204600000003],[-122.08641999999999,37.272007],[-122.09154999999998,37.268237],[-122.09528900000001,37.268719999999995],[-122.09527200000002,37.264665000000036],[-122.09960799999996,37.26463400000005],[-122.09964799999997,37.26816100000002],[-122.103897,37.26846700000002],[-122.10365399999996,37.26461000000002],[-122.10404599999998,37.265906000000044],[-122.107463,37.26592999999999],[-122.10751099999997,37.264594000000024],[-122.11281299999999,37.26450800000001],[-122.11292999999999,37.27190000000003],[-122.143326,37.27229500000003],[-122.14373899999998,37.286521999999984],[-122.15240399999999,37.28690499999997],[-122.14869,37.28099999999997],[-122.15053899999995,37.275882999999986],[-122.14836199999995,37.27545100000003],[-122.14414999999997,37.27021],[-122.13584999999996,37.26573999999999],[-122.13166000000002,37.26093],[-122.121638,37.25856000000002],[-122.10556999999996,37.24073999999996],[-122.10423000000002,37.23427000000002],[-122.09951000000002,37.23320000000004],[-122.09336899999995,37.22924000000004],[-122.09266699999995,37.22544000000004],[-122.08981,37.22326999999999],[-122.07877400000001,37.222974000000015],[-122.07000999999998,37.21667200000004],[-122.06593299999997,37.210412999999974],[-122.06397999999994,37.21011100000003],[-122.058404,37.213070999999985],[-122.05840000000002,37.217057000000004],[-122.03550000000001,37.21685100000001],[-122.03543699999996,37.21339800000004],[-122.03090599999996,37.213504000000015],[-122.03106499999997,37.22401100000002],[-122.01805899999997,37.22449500000001],[-122.01831099999994,37.228252000000005],[-122.00836100000002,37.228583000000036],[-122.00582,37.226980000000005],[-122.00431799999998,37.22864799999999],[-121.99932799999993,37.22790000000001],[-121.99674200000003,37.230723],[-121.99239699999995,37.22839999999999],[-121.98955300000002,37.23175400000004],[-121.992259,37.23273200000004],[-121.98958899999997,37.23416500000004],[-121.99518,37.23861000000002],[-121.99144299999999,37.24343000000004],[-121.99709899999998,37.243908999999974],[-121.99521,37.246725],[-121.99542499999994,37.25028800000002],[-122.00453200000001,37.25038700000004],[-122.003073,37.254436000000034],[-122.00022000000003,37.25606000000002],[-122.00441999999998,37.25720000000002],[-122.00455399999997,37.26773099999997],[-121.99930899999997,37.268865999999996],[-122.00301599999999,37.27050899999996],[-122.00286500000003,37.279084999999974],[-122.00434000000003,37.27994000000002],[-122.007194,37.277210999999994],[-122.00931699999998,37.27866600000004]]],[[[-122.16216100000003,37.293870999999996],[-122.15623399999998,37.291811999999986],[-122.15256999999995,37.28821999999997],[-122.151947,37.29438100000001],[-122.13516699999994,37.29365499999998],[-122.13508300000001,37.29726799999996],[-122.15694500000001,37.29781400000002],[-122.15704199999996,37.29397100000001],[-122.16002299999995,37.29815399999999],[-122.16216100000003,37.293870999999996]]],[[[-122.16272699999996,37.30073099999996],[-122.16683800000001,37.29523700000004],[-122.163025,37.29392400000003],[-122.16448700000001,37.294950000000014],[-122.16442299999996,37.29764799999996],[-122.16156999999997,37.30122000000001],[-122.16231199999999,37.303772000000045],[-122.16272699999996,37.30073099999996]]],[[[-122.16823,37.30780700000003],[-122.16658399999996,37.30561700000002],[ ...

# %%
x = random.randint(0, 13057)
print(x)
print(school_holidays.iloc[x]['GEO'])
multipolygon_plotter(school_holidays.iloc[x]['GEO'])
# Out:
# 4830
# {"coordinates":[[[-121.11124199999998,41.995672000000035],[-121.16847700000002,41.99717800000003],[-121.20090299999995,41.99742700000002],[-121.24724399999997,41.99728799999999],[-121.29021099999996,41.99743599999997],[-121.32881200000001,41.99680200000001],[-121.34491099999997,41.99621400000003],[-121.35939900000002,41.99655899999997],[-121.36323699999997,41.99649899999998],[-121.54631700000002,41.99851200000001],[-121.68061900000004,42.00040800000003],[-121.68054800000002,41.99312299999999],[-121.68093599999997,41.951557],[-121.68130700000002,41.93862100000002],[-121.67769499999994,41.93790500000002],[-121.67805000000001,41.93789000000002],[-121.67802100000002,41.93776499999998],[-121.67773899999995,41.93776499999998],[-121.67896199999997,41.89282599999998],[-121.68085999999998,41.892282],[-121.68249200000001,41.89206599999998],[-121.68258499999999,41.86351700000002],[-121.63726799999998,41.86287600000001],[-121.62678200000002,41.862602999999986],[-121.61385599999997,41.86270000000001],[-121.58542300000002,41.86254899999995],[-121.58541699999996,41.862411],[-121.56897899999996,41.86191599999999],[-121.569103,41.81207999999999],[-121.56897199999999,41.776069],[-121.55268800000002,41.775997],[-121.54186000000001,41.77535599999998],[-121.51361299999999,41.77604],[-121.50751600000001,41.776025999999995],[-121.50745800000001,41.72060899999999],[-121.52682699999998,41.720565],[-121.52682699999998,41.705861000000006],[-121.52658299999995,41.70611900000004],[-121.50750100000002,41.706041999999975],[-121.48828999999998,41.70616999999999],[-121.48837899999997,41.74958300000004],[-121.48822600000001,41.77583699999999],[-121.48739599999999,41.775858000000035],[-121.487394,41.776174999999974],[-121.44898099999995,41.776391999999994],[-121.44938000000002,41.750003999999954],[-121.44916100000002,41.69202000000002],[-121.448564,41.656889],[-121.44972299999998,41.62487699999996],[-121.44919100000001,41.621435],[-121.44911399999994,41.61386200000002],[-121.44855599999995,41.53922700000002],[-121.44882799999999,41.51671800000003],[-121.37726599999996,41.516843999999985],[-121.356274,41.51673999999999],[-121.35132299999998,41.51652900000003],[-121.34841699999997,41.51676100000004],[-121.33438499999998,41.516956000000015],[-121.18672899999994,41.51739799999999],[-121.18089799999994,41.51720600000001],[-121.17425100000001,41.517428999999986],[-121.10595499999995,41.517542999999996],[-121.10546899999997,41.617477999999984],[-121.10550500000002,41.632451000000025],[-121.10570899999993,41.63377099999999],[-121.10539000000001,41.634291000000026],[-121.10551499999995,41.64474300000001],[-121.10545099999999,41.67033300000001],[-121.10527799999998,41.67992699999997],[-121.10511999999996,41.72576400000002],[-121.10485499999997,41.73386100000001],[-121.10505000000003,41.73464700000003],[-121.10502099999994,41.75744600000002],[-121.10228099999999,41.76763200000003],[-121.10168599999996,41.77473300000003],[-121.11248299999998,41.774863000000046],[-121.11250700000001,41.78659000000001],[-121.11182899999996,41.79392500000002],[-121.11108399999995,41.808061999999985],[-121.11182000000001,41.817705],[-121.11157000000001,41.82049000000004],[-121.11124099999998,41.829707999999975],[-121.11118199999999,41.91602700000002],[-121.111779,41.937838999999975],[-121.11240300000001,41.93876800000002],[-121.111764,41.93968299999995],[-121.11246200000002,41.943249000000044],[-121.11235399999997,41.94407799999998],[-121.11194499999996,41.94519099999997],[-121.11157799999997,41.94572100000003],[-121.111952,41.946048999999995],[-121.11130099999997,41.95745600000003],[-121.11124199999998,41.995672000000035]]],"type":"Polygon"}

# %%
# Specify the folder path 
folder_path = '../../data_CityEvent/processed/1.4_updated_events_cbgid_assigned_by_category'
file_names = os.listdir(folder_path)

# %%
non_attended_df = pd.DataFrame()
for file_name in file_names:
    if file_name[0] == 'a' or file_name[0] == 'u':
        continue
    print(file_name)
    df = pd.read_csv(f'../../data_CityEvent/processed/1.4.4_updated_cbgid_downscaled/{file_name}')
    print(df.shape)
    df = df[df['EVENT_ID'].duplicated(keep=False) == False]
    print(df.shape)

    non_attended_df = pd.concat([non_attended_df, df], ignore_index=True)
    print(non_attended_df.shape)
# Out:
# non_attended_academic.csv
# (5275, 7)
# (5275, 7)
# (5275, 7)
# non_attended_observances.csv
# (13, 7)
# (13, 7)
# (5288, 7)
# non_attended_public-holidays.csv
# (50, 7)
# (50, 7)
# (5338, 7)
# non_attended_school-holidays.csv
# (588362, 7)
# (3, 7)
# (5341, 7)

# %%
x = non_attended_df[non_attended_df['CATEGORY']=='school-holidays']
x
# Out:
#                 EVENT_ID         CATEGORY  \
# 5338  9Xy5Tfydj5FwZMwVyC  school-holidays
# 5339  6UpkYbyujyhLurjzkT  school-holidays
# 5340  E7hJmC2zphQu8mqezf  school-holidays
#
#                                                     GEO   EVENT_START_BOSTON  \
# 5338  {"coordinates":[[[-119.43740400000002,35.67399...  2021-03-27 03:00:00
# 5339  {"coordinates":[[[-119.43740400000002,35.67399...  2020-11-21 03:00:00
# 5340  {"coordinates":[[[-119.43740400000002,35.67399...  2020-12-12 03:00:00
#
#          EVENT_END_BOSTON geometry        GEOID
# 5338  2021-04-06 02:59:59     None  60290045002
# 5339  2020-11-30 02:59:59     None  60290045002
# 5340  2021-01-04 02:59:59     None  60290045002

# %%
spatial_dist_of_events(non_attended_df, 'non-attended events')

# %%
# Specify the folder path 
folder_path = '../../data_CityEvent/processed/1.4_updated_events_cbgid_assigned_by_category'
file_names = os.listdir(folder_path)
for file_name in file_names:
    if file_name[0] == 'a' or file_name[0] == 'n':
        continue
    print(file_name)
# Out:
# unscheduled_airport-delays.csv
# unscheduled_disasters.csv
# unscheduled_health-warnings.csv
# unscheduled_severe-weather.csv
# unscheduled_terror.csv

# %%
parent_df = pd.DataFrame()
for file_name in file_names:
    if file_name[0] == 'a' or file_name[0] == 'n':
        continue
    print(file_name)
    df = pd.read_csv(f'../../data_CityEvent/processed/1.4.4_updated_cbgid_downscaled/{file_name}')
    print(df.shape)
    df = df[df['EVENT_ID'].duplicated(keep=False) == False]
    print(df.shape)

    parent_df = pd.concat([parent_df, df], ignore_index=True)
    print(parent_df.shape)
# Out:
# unscheduled_airport-delays.csv
# (31612, 7)
# (31612, 7)
# (31612, 7)
# unscheduled_disasters.csv
# (72808, 7)
# (1315, 7)
# (32927, 7)
# unscheduled_health-warnings.csv
# (39, 7)
# (39, 7)
# (32966, 7)
# unscheduled_severe-weather.csv
# (2106605, 7)
# (291, 7)
# (33257, 7)
# unscheduled_terror.csv
# (133, 7)
# (133, 7)
# (33390, 7)

# %%
spatial_dist_of_events(parent_df, 'unscheduled events')
